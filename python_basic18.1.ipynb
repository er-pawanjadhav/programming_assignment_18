# %%
def num_ret(a):
    b = []
    for i in a:
        if type(i)==int:
            b.append(i)
    return b

a = [1, "a", "b", 0, 15,-10,-8,-9]
b = []
for i in a:
    if type(i)==int:
        if i<0:
            pass
        else:
            b.append(i)
    else:
        b.append(i)

c =num_ret(b)
print(c)
# Out:
# [1, 0, 15]
