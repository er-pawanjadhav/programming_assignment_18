# %%
def function1(a,b,c):
    while b  in a:
        a.remove(b)
    for i in range(c):
        a.append(b)
    return a

a = [1, 3, 2, 4,1, 4, 1,1]
b = 1
c=a.count(b)
print(function1(a,b,c))
# Out:
# [3, 2, 4, 4, 1, 1, 1, 1]
